# %% [markdown]
# ## 패키지 Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
from keras.preprocessing import image

import os
import cv2
import PIL
import shutil
import keras

import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array
# 이미지 데이터 증강
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 옵티마이저
from tensorflow.keras.optimizers import RMSprop

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
# 파일 압축 풀기
# %cd 압축을 풀 경로
# !unzip -qq "압축파일 Path"

# %cd /content/drive/MyDrive/6dogma/res
# !unzip -qq "/content/drive/MyDrive/6dogma/res/resized.zip"
# Out:
# /content/drive/MyDrive/6dogma/res

# %% [markdown]
# ## 이미지 데이터 불러오기

# %%
# 기본 경로
base_dir = '/content/drive/MyDrive/6dogma/res/resized_aug/'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# 훈련용 Good/Bad 이미지 경로
train_G_dir = os.path.join(train_dir, 'Good')
train_B_dir = os.path.join(train_dir, 'bad')
print(train_G_dir, train_B_dir)

# 테스트용 Good/Bad 이미지 경로
test_G_dir = os.path.join(test_dir, 'Good')
test_B_dir = os.path.join(test_dir, 'bad')
print(test_G_dir, test_B_dir)
# Out:
# /content/drive/MyDrive/6dogma/res/resized_aug/train/Good /content/drive/MyDrive/6dogma/res/resized_aug/train/bad
# /content/drive/MyDrive/6dogma/res/resized_aug/test/Good /content/drive/MyDrive/6dogma/res/resized_aug/test/bad

# %%
# 훈련용 이미지 파일 이름 조회

train_G_fnames = os.listdir(train_G_dir)
train_B_fnames = os.listdir(train_B_dir)
print(train_G_fnames)
print(train_B_fnames)
# Out:
# ['KEMP_IMG_DATA_1107.png', 'KEMP_IMG_DATA_1106.png', 'KEMP_IMG_DATA_1108.png', 'KEMP_IMG_DATA_111.png', 'KEMP_IMG_DATA_1109.png', 'KEMP_IMG_DATA_1110.png', 'KEMP_IMG_DATA_1112.png', 'KEMP_IMG_DATA_1111.png', 'KEMP_IMG_DATA_1113.png', 'KEMP_IMG_DATA_1115.png', 'KEMP_IMG_DATA_1117.png', 'KEMP_IMG_DATA_1118.png', 'KEMP_IMG_DATA_1119.png', 'KEMP_IMG_DATA_112.png', 'KEMP_IMG_DATA_1122.png', 'KEMP_IMG_DATA_1124.png', 'KEMP_IMG_DATA_1126.png', 'KEMP_IMG_DATA_1125.png', 'KEMP_IMG_DATA_1127.png', 'KEMP_IMG_DATA_1129.png', 'KEMP_IMG_DATA_1128.png', 'KEMP_IMG_DATA_113.png', 'KEMP_IMG_DATA_1133.png', 'KEMP_IMG_DATA_1134.png', 'KEMP_IMG_DATA_1135.png', 'KEMP_IMG_DATA_1136.png', 'KEMP_IMG_DATA_1138.png', 'KEMP_IMG_DATA_1139.png', 'KEMP_IMG_DATA_114.png', 'KEMP_IMG_DATA_1140.png', 'KEMP_IMG_DATA_1141.png', 'KEMP_IMG_DATA_1144.png', 'KEMP_IMG_DATA_1145.png', 'KEMP_IMG_DATA_1146.png', 'KEMP_IMG_DATA_1147.png', 'KEMP_IMG_DATA_1148.png', 'KEMP_IMG_DATA_1149.png', 'KEMP_IMG_DATA_1150.png', 'KEMP_IMG_DATA_1151.png', 'KEMP_IMG_DATA_1152.png', 'KEMP_IMG_DATA_1153.png', 'KEMP_IMG_DATA_1154.png', 'KEMP_IMG_DATA_1155.png', 'KEMP_IMG_DATA_1156.png', 'KEMP_IMG_DATA_1157.png', 'KEMP_IMG_DATA_1158.png', 'KEMP_IMG_DATA_1159.png', 'KEMP_IMG_DATA_116.png', 'KEMP_IMG_DATA_1163.png', 'KEMP_IMG_DATA_1160.png', 'KEMP_IMG_DATA_1165.png', 'KEMP_IMG_DATA_1167.png', 'KEMP_IMG_DATA_1166.png', 'KEMP_IMG_DATA_1168.png', 'KEMP_IMG_DATA_117.png', 'KEMP_IMG_DATA_1169.png', 'KEMP_IMG_DATA_1172.png', 'KEMP_IMG_DATA_1174.png', 'KEMP_IMG_DATA_1173.png', 'KEMP_IMG_DATA_1175.png', 'KEMP_IMG_DATA_1176.png', 'KEMP_IMG_DATA_1177.png', 'KEMP_IMG_DATA_1179.png', 'KEMP_IMG_DATA_118.png', 'KEMP_IMG_DATA_1182.png', 'KEMP_IMG_DATA_1180.png', 'KEMP_IMG_DATA_1185.png', 'KEMP_IMG_DATA_1188.png', 'KEMP_IMG_DATA_1186.png', 'KEMP_IMG_DATA_1189.png', 'KEMP_IMG_DATA_119.png', 'KEMP_IMG_DATA_1190.png', 'KEMP_IMG_DATA_1191.png', 'KEMP_IMG_DATA_1192.png', 'KEMP_IMG_DATA_1193.png', 'KEMP_IMG_DATA_1194.png', 'KEMP_IMG_DATA_1195.png', 'KEMP_IMG_DATA_1198.png', 'KEMP_IMG_DATA_1196.png', 'KEMP_IMG_DATA_120.png', 'KEMP_IMG_DATA_1200.png', 'KEMP_IMG_DATA_1201.png', 'KEMP_IMG_DATA_1202.png', 'KEMP_IMG_DATA_1204.png', 'KEMP_IMG_DATA_1203.png', 'KEMP_IMG_DATA_1205.png', 'KEMP_IMG_DATA_1208.png', 'KEMP_IMG_DATA_1206.png', 'KEMP_IMG_DATA_1209.png', 'KEMP_IMG_DATA_121.png', 'KEMP_IMG_DATA_1210.png', 'KEMP_IMG_DATA_1212.png', 'KEMP_IMG_DATA_1213.png', 'KEMP_IMG_DATA_1214.png', 'KEMP_IMG_DATA_1215.png', 'KEMP_IMG_DATA_1217.png', 'KEMP_IMG_DATA_1219.png', 'KEMP_IMG_DATA_122.png', 'KEMP_IMG_DATA_1221.png', 'KEMP_IMG_DATA_1222.png', 'KEMP_IMG_DATA_1223.png', 'KEMP_IMG_DATA_1224.png', 'KEMP_IMG_DATA_1225.png', 'KEMP_IMG_DATA_1226.png', 'KEMP_IMG_DATA_1229.png', 'KEMP_IMG_DATA_123.png', 'KEMP_IMG_DATA_1230.png', 'KEMP_IMG_DATA_1231.png', 'KEMP_IMG_DATA_1232.png', 'KEMP_IMG_DATA_1234.png', 'KEMP_IMG_DATA_1233.png', 'KEMP_IMG_DATA_1235.png', 'KEMP_IMG_DATA_1237.png', 'KEMP_IMG_DATA_1236.png', 'KEMP_IMG_DATA_1238.png', 'KEMP_IMG_DATA_1240.png', 'KEMP_IMG_DATA_124.png', 'KEMP_IMG_DATA_1241.png', 'KEMP_IMG_DATA_1242.png', 'KEMP_IMG_DATA_1244.png', 'KEMP_IMG_DATA_1243.png', 'KEMP_IMG_DATA_1245.png', 'KEMP_IMG_DATA_1246.png', 'KEMP_IMG_DATA_1247.png', 'KEMP_IMG_DATA_1248.png', 'KEMP_IMG_DATA_125.png', 'KEMP_IMG_DATA_1249.png', 'KEMP_IMG_DATA_1251.png', 'KEMP_IMG_DATA_1252.png', 'KEMP_IMG_DATA_1253.png', 'KEMP_IMG_DATA_1254.png', 'KEMP_IMG_DATA_1256.png', 'KEMP_IMG_DATA_1255.png', 'KEMP_IMG_DATA_1257.png', 'KEMP_IMG_DATA_1258.png', 'KEMP_IMG_DATA_1259.png', 'KEMP_IMG_DATA_126.png', 'KEMP_IMG_DATA_1260.png', 'KEMP_IMG_DATA_1263.png', 'KEMP_IMG_DATA_1262.png', 'KEMP_IMG_DATA_1264.png', 'KEMP_IMG_DATA_1266.png', 'KEMP_IMG_DATA_1265.png', 'KEMP_IMG_DATA_1267.png', 'KEMP_IMG_DATA_1268.png', 'KEMP_IMG_DATA_1269.png', 'KEMP_IMG_DATA_127.png', 'KEMP_IMG_DATA_1274.png', 'KEMP_IMG_DATA_1275.png', 'KEMP_IMG_DATA_1276.png', 'KEMP_IMG_DATA_1278.png', 'KEMP_IMG_DATA_1281.png', 'KEMP_IMG_DATA_1279.png', 'KEMP_IMG_DATA_1282.png', 'KEMP_IMG_D ...
# ['Error_train_(107).png', 'Error_train_(101).png', 'Error_train_(111).png', 'Error_train_(119).png', 'Error_train_(112).png', 'Error_train_(113).png', 'Error_train_(118).png', 'Error_train_(106).png', 'Error_train_(114).png', 'Error_train_(102).png', 'Error_train_(103).png', 'Error_train_(105).png', 'Error_train_(108).png', 'Error_train_(116).png', 'Error_train_(121).png', 'Error_train_(120).png', 'Error_train_(109).png', 'Error_train_(110).png', 'Error_train_(115).png', 'Error_train_(104).png', 'Error_train_(117).png', 'Error_train_(100).png', 'Error_train_(130).png', 'Error_train_(132).png', 'Error_train_(124).png', 'Error_train_(141).png', 'Error_train_(136).png', 'Error_train_(134).png', 'Error_train_(137).png', 'Error_train_(138).png', 'Error_train_(127).png', 'Error_train_(139).png', 'Error_train_(125).png', 'Error_train_(135).png', 'Error_train_(133).png', 'Error_train_(123).png', 'Error_train_(143).png', 'Error_train_(128).png', 'Error_train_(122).png', 'Error_train_(140).png', 'Error_train_(126).png', 'Error_train_(142).png', 'Error_train_(131).png', 'Error_train_(129).png', 'Error_train_(146).png', 'Error_train_(144).png', 'Error_train_(153).png', 'Error_train_(154).png', 'Error_train_(149).png', 'Error_train_(147).png', 'Error_train_(152).png', 'Error_train_(145).png', 'Error_train_(151).png', 'Error_train_(148).png', 'Error_train_(150).png', 'Error_train_(164).png', 'Error_train_(161).png', 'Error_train_(159).png', 'Error_train_(155).png', 'Error_train_(163).png', 'Error_train_(165).png', 'Error_train_(157).png', 'Error_train_(162).png', 'Error_train_(158).png', 'Error_train_(160).png', 'Error_train_(156).png', 'Error_train_(183).png', 'Error_train_(175).png', 'Error_train_(178).png', 'Error_train_(187).png', 'Error_train_(186).png', 'Error_train_(185).png', 'Error_train_(171).png', 'Error_train_(184).png', 'Error_train_(166).png', 'Error_train_(168).png', 'Error_train_(181).png', 'Error_train_(180).png', 'Error_train_(167).png', 'Error_train_(182).png', 'Error_train_(179).png', 'Error_train_(169).png', 'Error_train_(176).png', 'Error_train_(173).png', 'Error_train_(170).png', 'Error_train_(177).png', 'Error_train_(172).png', 'Error_train_(174).png', 'Error_train_(195).png', 'Error_train_(198).png', 'Error_train_(202).png', 'Error_train_(197).png', 'Error_train_(204).png', 'Error_train_(207).png', 'Error_train_(203).png', 'Error_train_(200).png', 'Error_train_(194).png', 'Error_train_(201).png', 'Error_train_(206).png', 'Error_train_(199).png', 'Error_train_(209).png', 'Error_train_(193).png', 'Error_train_(192).png', 'Error_train_(205).png', 'Error_train_(189).png', 'Error_train_(188).png', 'Error_train_(190).png', 'Error_train_(196).png', 'Error_train_(208).png', 'Error_train_(191).png', 'Error_train_(13).png', 'Error_train_(16).png', 'Error_train_(18).png', 'Error_train_(17).png', 'Error_train_(15).png', 'Error_train_(12).png', 'Error_train_(14).png', 'Error_train_(19).png', 'Error_train_(21).png', 'Error_train_(22).png', 'Error_train_(20).png', 'Error_train_(316).png', 'Error_train_(318).png', 'Error_train_(315).png', 'Error_train_(309).png', 'Error_train_(314).png', 'Error_train_(313).png', 'Error_train_(310).png', 'Error_train_(317).png', 'Error_train_(311).png', 'Error_train_(312).png', 'Error_train_(319).png', 'Error_train_(343).png', 'Error_train_(347).png', 'Error_train_(351).png', 'Error_train_(333).png', 'Error_train_(338).png', 'Error_train_(342).png', 'Error_train_(346).png', 'Error_train_(341).png', 'Error_train_(350).png', 'Error_train_(336).png', 'Error_train_(326).png', 'Error_train_(331).png', 'Error_train_(325).png', 'Error_train_(328).png', 'Error_train_(344).png', 'Error_train_(330).png', 'Error_train_(321).png', 'Error_train_(322).png', 'Error_train_(327).png', 'Error_train_(345).png', 'Error_train_(352).png', 'Error_train_(332).png', 'Error_train_(349).png', 'Error_train_(340).png', 'Error_train_(324).png', 'Error_train_(339).png', 'Error_train_(323).png', 'Error_train_(335).png', 'Error_tra ...

# %%
# 각 디렉토리에 저장되어 있는 이미지 파일 수 확인

print('Total training G images :', len(os.listdir(train_G_dir)))
print('Total training B images :', len(os.listdir(train_B_dir)))

print('Total test G images :', len(os.listdir(test_G_dir)))
print('Total test B images :', len(os.listdir(test_B_dir)))
# Out:
# Total training G images : 1102
# Total training B images : 649
# Total test G images : 275
# Total test B images : 164

# %%
# 이미지 확인

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_G_pix = [os.path.join(train_G_dir, fname) for fname in train_G_fnames[pic_index-8:pic_index]]
next_B_pix = [os.path.join(train_B_dir, fname) for fname in train_B_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_G_pix+next_B_pix):
    sp = plt.subplot(nrows, ncols, i+1)
    sp.axis('OFF')
    
    img = mpimg.imread(img_path)
    plt.imshow(img)
    
plt.show()

# %% [markdown]
# ## 이미지 데이터 생성

# %%
# Image augmentation
# train셋에만 적용
train_datagen = ImageDataGenerator(rescale = 1./255, # 모든 이미지 원소값들을 255로 나누기
                                   rotation_range=25, # 0~25도 사이에서 임의의 각도로 원본이미지를 회전
                                   width_shift_range=0.05, # 0.05범위 내에서 임의의 값만큼 임의의 방향으로 좌우 이동
                                   height_shift_range=0.05, # 0.05범위 내에서 임의의 값만큼 임의의 방향으로 상하 이동
                                   horizontal_flip=True, # 좌우로 뒤집기                                   
                                   vertical_flip=True,  # 상하로 뒤집기
                                   fill_mode='nearest'
                                  ) 
test_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=25,
                                   width_shift_range=0.05,
                                   height_shift_range=0.05,
                                   horizontal_flip=True,                                   
                                   vertical_flip=True,
                                   fill_mode='nearest'
                                  )

# %%
# flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만들기
# 변환된 이미지 데이터 생성
train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    batch_size=64, # 한번에 변환된 이미지 16개씩 만들어라 라는 것
                                                    color_mode='grayscale', # 흑백 이미지 처리
                                                    class_mode='binary', 
                                                    target_size=(256,256)) # target_size에 맞춰서 이미지의 크기가 조절된다

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  batch_size=32,
                                                  color_mode='grayscale',
                                                  class_mode='binary',
                                                  target_size=(256,256))
# 참고로, generator 생성시 batch_size x steps_per_epoch (model fit에서) <= 훈련 샘플 수 보다 작거나 같아야 한다.
# Out:
# Found 1751 images belonging to 2 classes.
# Found 439 images belonging to 2 classes.

# %%
# class 확인
train_generator.class_indices
# Out:
# {'Good': 0, 'bad': 1}

# %% [markdown]
# ## Augmentation 적용 확인

# %%
# 이미지 하나 불러오기
sample_img = mpimg.imread(next_G_pix[0])
plt.imshow(sample_img)
plt.show()

# %%
max_iter = 4
cnt = 1
sample_img2 = sample_img[np.newaxis, ...]
# 축을 하나 추가했는데, 하나의 이미지만 바꿔주는게 아니라 동시에 여러개의 이미지를 바꿔줄 수 있기에,
# 그림 개수/장수 까지 받아서 4차원으로 (개수/장수, h, w, channel) 이렇게 받는다
# 쉽게 말해, 받는 형식이 4차원이라서 4차원 형태로 만들어 준것

plt.figure(figsize=(10,10))
for img in train_datagen.flow(sample_img2):
    plt.subplot(1, max_iter, cnt)
    plt.imshow(image.array_to_img(img[0]))
    if cnt == max_iter:
        break
    cnt += 1

# %%
sample_img.shape
# Out:
# (720, 480, 4)

# %% [markdown]
# ## 모델링
#
# - 합성곱 신경망 모델 구성
# - 출력층의 활성화함수로 'sigmoid' 사용
#   - 0과 1 두 가지로 분류되는 'binary' 분류 문제에 적합하기 때문

# %%
# 합성곱 신경망 모델 구성하기
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary() # 신경망의 구조 확인
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      160
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 28800)             0
#
#  dense_2 (Dense)             (None, 512)               14746112
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 14,760,673
# Trainable params: 14,760,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4dadc2621d67> in <module>
# ----> 1 input_shape
#
# NameError: name 'input_shape' is not defined

# %% [markdown]
# ## 모델 학습
#
# - 손실 함수로 ‘binary_crossentropy’를 사용
# - 옵티마이저로는 RMSprop을 사용
#   - RMSprop(Root Mean Square Propagation) 알고리즘은 훈련 과정 중에 학습률을 적절하게 변화시켜 줌

# %%
# 모델 컴파일
# compile() 메서드를 이용해서 손실 함수 (loss function)와 옵티마이저 (optimizer)를 지정
model.compile(optimizer=RMSprop(learning_rate=0.001), # 옵티마이저로는 RMSprop 사용
              loss='binary_crossentropy', # 손실 함수로 ‘binary_crossentropy’ 사용
              metrics= ['accuracy'])

# %%
# 모델 훈련
history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
                              validation_data=test_generator, # validatino_generator안에도 검증용 X,y데이터들이 다 있으니 generator로 주면 됨
                              steps_per_epoch=16, # 한 번의 에포크(epoch)에서 훈련에 사용할 배치(batch)의 개수 지정; generator를 4번 부르겠다
                              epochs=50, # 데이터셋을 한 번 훈련하는 과정; epoch은 100 이상은 줘야한다
                              validation_steps=16, # 한 번의 에포크가 끝날 때, 검증에 사용되는 배치(batch)의 개수를 지정; validation_generator를 4번 불러서 나온 이미지들로 작업을 해라
                              verbose=2)
# 참고: validation_steps는 보통 내가 원하는 이미지 수에 flow할 때 지정한 batchsize로 나눈 값을 validation_steps로 지정
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 16 batches). You may need to use the repeat() function when building your dataset.
# 16/16 - 166s - loss: 0.5752 - accuracy: 0.7375 - val_loss: 0.4130 - val_accuracy: 0.8519 - 166s/epoch - 10s/step
# Epoch 2/50
# 16/16 - 25s - loss: 0.4399 - accuracy: 0.7998 - 25s/epoch - 2s/step
# Epoch 3/50
# 16/16 - 21s - loss: 0.2261 - accuracy: 0.9248 - 21s/epoch - 1s/step
# Epoch 4/50
# 16/16 - 19s - loss: 0.1741 - accuracy: 0.9461 - 19s/epoch - 1s/step
# Epoch 5/50
# 16/16 - 20s - loss: 0.1862 - accuracy: 0.9434 - 20s/epoch - 1s/step
# Epoch 6/50
# 16/16 - 18s - loss: 0.1534 - accuracy: 0.9481 - 18s/epoch - 1s/step
# Epoch 7/50
# 16/16 - 18s - loss: 0.1399 - accuracy: 0.9563 - 18s/epoch - 1s/step
# Epoch 8/50
# 16/16 - 19s - loss: 0.1292 - accuracy: 0.9648 - 19s/epoch - 1s/step
# Epoch 9/50
# 16/16 - 19s - loss: 0.1656 - accuracy: 0.9521 - 19s/epoch - 1s/step
# Epoch 10/50
# 16/16 - 19s - loss: 0.1195 - accuracy: 0.9668 - 19s/epoch - 1s/step
# Epoch 11/50
# 16/16 - 19s - loss: 0.1465 - accuracy: 0.9512 - 19s/epoch - 1s/step
# Epoch 12/50
# 16/16 - 19s - loss: 0.1077 - accuracy: 0.9736 - 19s/epoch - 1s/step
# Epoch 13/50
# 16/16 - 19s - loss: 0.1319 - accuracy: 0.9563 - 19s/epoch - 1s/step
# Epoch 14/50
# 16/16 - 19s - loss: 0.0955 - accuracy: 0.9766 - 19s/epoch - 1s/step
# Epoch 15/50
# 16/16 - 19s - loss: 0.1774 - accuracy: 0.9481 - 19s/epoch - 1s/step
# Epoch 16/50
# 16/16 - 19s - loss: 0.0770 - accuracy: 0.9776 - 19s/epoch - 1s/step
# Epoch 17/50
# 16/16 - 19s - loss: 0.0841 - accuracy: 0.9685 - 19s/epoch - 1s/step
# Epoch 18/50
# 16/16 - 19s - loss: 0.1211 - accuracy: 0.9573 - 19s/epoch - 1s/step
# Epoch 19/50
# 16/16 - 19s - loss: 0.0591 - accuracy: 0.9817 - 19s/epoch - 1s/step
# Epoch 20/50
# 16/16 - 19s - loss: 0.0362 - accuracy: 0.9847 - 19s/epoch - 1s/step
# Epoch 21/50
# 16/16 - 20s - loss: 0.1218 - accuracy: 0.9434 - 20s/epoch - 1s/step
# Epoch 22/50
# 16/16 - 19s - loss: 0.0498 - accuracy: 0.9844 - 19s/epoch - 1s/step
# Epoch 23/50
# 16/16 - 18s - loss: 0.0304 - accuracy: 0.9908 - 18s/epoch - 1s/step
# Epoch 24/50
# 16/16 - 19s - loss: 0.0246 - accuracy: 0.9888 - 19s/epoch - 1s/step
# Epoch 25/50
# 16/16 - 19s - loss: 0.0309 - accuracy: 0.9922 - 19s/epoch - 1s/step
# Epoch 26/50
# 16/16 - 19s - loss: 0.0161 - accuracy: 0.9949 - 19s/epoch - 1s/step
# Epoch 27/50
# 16/16 - 20s - loss: 0.0589 - accuracy: 0.9834 - 20s/epoch - 1s/step
# Epoch 28/50
# 16/16 - 19s - loss: 0.0110 - accuracy: 0.9971 - 19s/epoch - 1s/step
# Epoch 29/50
# 16/16 - 19s - loss: 0.0078 - accuracy: 0.9980 - 19s/epoch - 1s/step
# Epoch 30/50
# 16/16 - 19s - loss: 0.2408 - accuracy: 0.9502 - 19s/epoch - 1s/step
# Epoch 31/50
# 16/16 - 19s - loss: 0.0425 - accuracy: 0.9834 - 19s/epoch - 1s/step
# Epoch 32/50
# 16/16 - 19s - loss: 0.0141 - accuracy: 0.9949 - 19s/epoch - 1s/step
# Epoch 33/50
# 16/16 - 19s - loss: 0.0064 - accuracy: 0.9969 - 19s/epoch - 1s/step
# Epoch 34/50
# 16/16 - 19s - loss: 0.0020 - accuracy: 1.0000 - 19s/epoch - 1s/step
# Epoch 35/50
# 16/16 - 19s - loss: 0.0282 - accuracy: 0.9908 - 19s/epoch - 1s/step
# Epoch 36/50
# 16/16 - 19s - loss: 0.0119 - accuracy: 0.9961 - 19s/epoch - 1s/step
# Epoch 37/50
# 16/16 - 19s - loss: 6.6547e-04 - accuracy: 1.0000 - 19s/epoch - 1s/step
# Epoch 38/50
# 16/16 - 20s - loss: 0.0302 - accuracy: 0.9932 - 20s/epoch - 1s/step
# Epoch 39/50
# 16/16 - 19s - loss: 0.0158 - accuracy: 0.9902 - 19s/epoch - 1s/step
# Epoch 40/50
# 16/16 - 19s - loss: 0.0012 - accuracy: 1.0000 - 19s/epoch - 1s/step
# Epoch 41/50
# 16/16 - 19s - loss: 4.8217e-04 - accuracy: 1.0000 - 19s/epoch - 1s/step
# Epoch 42/50
# 16/16 - 19s - loss: 1.3583 - accuracy: 0.9532 - 19s/epoch - 1s/step
# Epoch 43/50
# 16/16 - 18s - loss: 0.0322 - accuracy: 0.9929 - 18s/epoch - 1s/step
# Epoch 44/50
# 16/16 - 19s - loss: 0.0044 - accuracy: 0.9990 - 19s/epoch - 1s/step
# Epoch 45/50
# 16/16 - 18s - loss: 0.0025 - accuracy: 1.0000 - 18s/epoch - 1s/step
# Epoch 46/50
# 16/16 - 19s - loss: 0.0024 - accuracy: 0.9990 - 19s/epoch - 1s/step
# Epoch 47/50
# 16/16 - 18s - loss: 8.2033e-04 - accuracy: 1.0000 - 18s/epoch - 1s/step
# Epoch 48/50
# 16/16 - 19s - loss: 0.0011 - accuracy: 0.9990 - 19s/epoch - 1s/step
# Epoch 49/50
# 16/16 - 19s - loss: 0.0018 - accuracy: 1.0000 - 19s/epoch - 1s/step
# Epoch 50/50
# 16/16 - 19s - loss: 0.0508 - accuracy: 0.9786 - 19s/epoch - 1s/step

# %% [markdown]
# ## 모델 평가

# %%
# 모델 성능 평가
model.evaluate(train_generator)
# Out:
# 28/28 [==============================] - 33s 1s/step - loss: 0.0015 - accuracy: 0.9994
# [0.0015180265763774514, 0.9994288682937622]

# %%
model.evaluate(test_generator)
# Out:
# 14/14 [==============================] - 8s 592ms/step - loss: 0.0023 - accuracy: 1.0000
# [0.0023013027384877205, 1.0]

# %%
# 정확도 및 손실 시각화
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-c1909cea26e8> in <module>
#       8
#       9 plt.plot(epochs, acc, 'bo', label='Training accuracy')
# ---> 10 plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
#      11 plt.title('Training and validation accuracy')
#      12 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (1,)

# %%
# 테스트 평가
from keras.preprocessing import image

# 테스트용 Good 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma/res/only_test/'
test_G_dir = os.path.join(test_dir, 'Good/')
test_G_filenames = os.listdir(test_G_dir)
test_G_filenames

# 테스트용 Bad 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma/res/only_test/'
test_B_dir = os.path.join(test_dir, 'bad/')
test_B_filenames = os.listdir(test_B_dir)
test_B_filenames

# Good,bad를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_GB_filenames = {}
dic_GB_filenames['Good'] = test_G_filenames
dic_GB_filenames['bad'] = test_B_filenames

# Good/Bad 분류 테스트
for GB, filenames in dic_GB_filenames.items():
    fig = plt.figure(figsize=(16,10))
    rows, cols = 2, 8
    for i, fn in enumerate(filenames):
        path = test_dir + GB + '/' + fn
        test_img = keras.utils.load_img(path, color_mode='grayscale', target_size=(256, 256), interpolation='bilinear')        
        x = keras.utils.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = model.predict(images, batch_size=16)
        
        fig.add_subplot(rows, cols, i+1)
        if classes[0]==0:
            # plt.title(fn + " is Good")
            plt.title(" is Good")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')

        else:
            plt.title(" is Bad")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
    plt.show();
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
tr_parser = PetfinderImageParser(preproc_func, image_size, train_aug)
tr_datagen = PetfinderDataGenerator(
    filenames_tr, y_tr, tr_parser, 
    image_size=image_size,
    batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c80408b158d5> in <module>
# ----> 1 tr_parser = PetfinderImageParser(preproc_func, image_size, train_aug)
#       2 tr_datagen = PetfinderDataGenerator(
#       3     filenames_tr, y_tr, tr_parser,
#       4     image_size=image_size,
#       5     batch_size=batch_size)
#
# NameError: name 'preproc_func' is not defined

# %%
# # Image augmentation
# # train set
# train_datagen = ImageDataGenerator(rescale = 1./255, # 모든 이미지 원소값들을 255로 나누기
#                                    rotation_range=25, # 0~90도 사이에서 임의의 각도로 원본이미지를 회전
#                                    horizontal_flip=True, # 좌우로 뒤집기                                   
#                                    vertical_flip=True,  # 상하로 뒤집기
#                                    fill_mode='nearest'
#                                   )
# # test set
# test_datagen = ImageDataGenerator(rescale = 1./255, # 모든 이미지 원소값들을 255로 나누기
#                                    rotation_range=25, # 0~90도 사이에서 임의의 각도로 원본이미지를 회전
#                                    horizontal_flip=True, # 좌우로 뒤집기                                   
#                                    vertical_flip=True,  # 상하로 뒤집기
#                                    fill_mode='nearest'
#                                   ) 
# # validation 및 test 이미지는 augmentation을 적용하지 않는다;
# # 모델 성능을 평가할 때에는 이미지 원본을 사용 (rescale만 진행)
# test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만들기
# 변환된 이미지 데이터 생성
train_generator = train_aug.flow_from_directory(train_dir, 
                                                    batch_size=16, # 한번에 변환된 이미지 16개씩 만들어라 라는 것
                                                    color_mode='grayscale', # 흑백 이미지 처리
                                                    class_mode='binary', 
                                                    target_size=(256,256)) # target_size에 맞춰서 이미지의 크기가 조절된다
                                                    
test_generator = test_aug.flow_from_directory(test_dir,
                                                  batch_size=4,
                                                  color_mode='grayscale',
                                                  class_mode='binary',
                                                  target_size=(256,256))
# 참고로, generator 생성시 batch_size x steps_per_epoch (model fit에서) <= 훈련 샘플 수 보다 작거나 같아야 한다.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-60e18f985881> in <module>
#       1 # flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만들기
#       2 # 변환된 이미지 데이터 생성
# ----> 3 train_generator = train_aug.flow_from_directory(train_dir,
#       4                                                     batch_size=16, # 한번에 변환된 이미지 16개씩 만들어라 라는 것
#       5                                                     color_mode='grayscale', # 흑백 이미지 처리
#
# AttributeError: 'Compose' object has no attribute 'flow_from_directory'

# %%
# 라벨 확인
# class 확인
train_generator.class_indices
# Out:
# {'Good': 0, 'bad': 1}

# %% [markdown]
# ## 모델링

# %%
# 합성곱 신경망 모델 구성하기
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary() # 신경망의 구조 확인
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_7 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 28800)             0
#
#  dense_12 (Dense)            (None, 512)               14746112
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 128)               32896
#
#  dense_15 (Dense)            (None, 64)                8256
#
#  dense_16 (Dense)            (None, 32)                2080
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 14,935,041
# Trainable params: 14,935,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# compile() 메서드를 이용해서 손실 함수 (loss function)와 옵티마이저 (optimizer)를 지정
model.compile(optimizer=RMSprop(learning_rate=0.001), # 옵티마이저로는 RMSprop 사용
              loss='binary_crossentropy', # 손실 함수로 ‘binary_crossentropy’ 사용
              metrics= ['accuracy'])
# RMSprop (Root Mean Square Propagation) Algorithm: 훈련 과정 중에 학습률을 적절하게 변화시킨다.
