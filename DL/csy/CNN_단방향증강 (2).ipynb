# %% [markdown]
# ## 패키지 Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
from keras.preprocessing import image

import os
import cv2
import PIL
import shutil
import keras

import tensorflow as tf
from tensorflow.keras.utils import load_img, img_to_array
# 이미지 데이터 증강
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 옵티마이저
from tensorflow.keras.optimizers import RMSprop

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 파일 압축 풀기
# %cd 압축을 풀 경로
# !unzip -qq "압축파일 Path"

# %cd /content/drive/MyDrive/6dogma/res
# !unzip -qq "/content/drive/MyDrive/6dogma/res/resized.zip"
# Out:
# /content/drive/MyDrive/6dogma/res

# %% [markdown]
# ## 이미지 데이터 불러오기

# %%
# 기본 경로
base_dir = '/content/drive/MyDrive/6dogma_sy/res/resized_aug/'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# 훈련용 Good/Bad 이미지 경로
train_G_dir = os.path.join(train_dir, 'Good')
train_B_dir = os.path.join(train_dir, 'bad')
print(train_G_dir, train_B_dir)

# 테스트용 Good/Bad 이미지 경로
test_G_dir = os.path.join(test_dir, 'Good')
test_B_dir = os.path.join(test_dir, 'bad')
print(test_G_dir, test_B_dir)
# Out:
# /content/drive/MyDrive/6dogma_sy/res/resized_aug/train/Good /content/drive/MyDrive/6dogma_sy/res/resized_aug/train/bad
# /content/drive/MyDrive/6dogma_sy/res/resized_aug/test/Good /content/drive/MyDrive/6dogma_sy/res/resized_aug/test/bad

# %%
# 훈련용 이미지 파일 이름 조회

train_G_fnames = os.listdir(train_G_dir)
train_B_fnames = os.listdir(train_B_dir)
print(train_G_fnames)
print(train_B_fnames)
# Out:
# ['KEMP_IMG_DATA_1107.png', 'KEMP_IMG_DATA_1106.png', 'KEMP_IMG_DATA_1108.png', 'KEMP_IMG_DATA_111.png', 'KEMP_IMG_DATA_1109.png', 'KEMP_IMG_DATA_1110.png', 'KEMP_IMG_DATA_1112.png', 'KEMP_IMG_DATA_1111.png', 'KEMP_IMG_DATA_1113.png', 'KEMP_IMG_DATA_1115.png', 'KEMP_IMG_DATA_1117.png', 'KEMP_IMG_DATA_1118.png', 'KEMP_IMG_DATA_1119.png', 'KEMP_IMG_DATA_112.png', 'KEMP_IMG_DATA_1122.png', 'KEMP_IMG_DATA_1124.png', 'KEMP_IMG_DATA_1126.png', 'KEMP_IMG_DATA_1125.png', 'KEMP_IMG_DATA_1127.png', 'KEMP_IMG_DATA_1129.png', 'KEMP_IMG_DATA_1128.png', 'KEMP_IMG_DATA_113.png', 'KEMP_IMG_DATA_1133.png', 'KEMP_IMG_DATA_1134.png', 'KEMP_IMG_DATA_1135.png', 'KEMP_IMG_DATA_1136.png', 'KEMP_IMG_DATA_1138.png', 'KEMP_IMG_DATA_1139.png', 'KEMP_IMG_DATA_114.png', 'KEMP_IMG_DATA_1140.png', 'KEMP_IMG_DATA_1141.png', 'KEMP_IMG_DATA_1144.png', 'KEMP_IMG_DATA_1145.png', 'KEMP_IMG_DATA_1146.png', 'KEMP_IMG_DATA_1147.png', 'KEMP_IMG_DATA_1148.png', 'KEMP_IMG_DATA_1149.png', 'KEMP_IMG_DATA_1150.png', 'KEMP_IMG_DATA_1151.png', 'KEMP_IMG_DATA_1152.png', 'KEMP_IMG_DATA_1153.png', 'KEMP_IMG_DATA_1154.png', 'KEMP_IMG_DATA_1155.png', 'KEMP_IMG_DATA_1156.png', 'KEMP_IMG_DATA_1157.png', 'KEMP_IMG_DATA_1158.png', 'KEMP_IMG_DATA_1159.png', 'KEMP_IMG_DATA_116.png', 'KEMP_IMG_DATA_1163.png', 'KEMP_IMG_DATA_1160.png', 'KEMP_IMG_DATA_1165.png', 'KEMP_IMG_DATA_1167.png', 'KEMP_IMG_DATA_1166.png', 'KEMP_IMG_DATA_1168.png', 'KEMP_IMG_DATA_117.png', 'KEMP_IMG_DATA_1169.png', 'KEMP_IMG_DATA_1172.png', 'KEMP_IMG_DATA_1174.png', 'KEMP_IMG_DATA_1173.png', 'KEMP_IMG_DATA_1175.png', 'KEMP_IMG_DATA_1176.png', 'KEMP_IMG_DATA_1177.png', 'KEMP_IMG_DATA_1179.png', 'KEMP_IMG_DATA_118.png', 'KEMP_IMG_DATA_1182.png', 'KEMP_IMG_DATA_1180.png', 'KEMP_IMG_DATA_1185.png', 'KEMP_IMG_DATA_1188.png', 'KEMP_IMG_DATA_1186.png', 'KEMP_IMG_DATA_1189.png', 'KEMP_IMG_DATA_119.png', 'KEMP_IMG_DATA_1190.png', 'KEMP_IMG_DATA_1191.png', 'KEMP_IMG_DATA_1192.png', 'KEMP_IMG_DATA_1193.png', 'KEMP_IMG_DATA_1194.png', 'KEMP_IMG_DATA_1195.png', 'KEMP_IMG_DATA_1198.png', 'KEMP_IMG_DATA_1196.png', 'KEMP_IMG_DATA_120.png', 'KEMP_IMG_DATA_1200.png', 'KEMP_IMG_DATA_1201.png', 'KEMP_IMG_DATA_1202.png', 'KEMP_IMG_DATA_1204.png', 'KEMP_IMG_DATA_1203.png', 'KEMP_IMG_DATA_1205.png', 'KEMP_IMG_DATA_1208.png', 'KEMP_IMG_DATA_1206.png', 'KEMP_IMG_DATA_1209.png', 'KEMP_IMG_DATA_121.png', 'KEMP_IMG_DATA_1210.png', 'KEMP_IMG_DATA_1212.png', 'KEMP_IMG_DATA_1213.png', 'KEMP_IMG_DATA_1214.png', 'KEMP_IMG_DATA_1215.png', 'KEMP_IMG_DATA_1217.png', 'KEMP_IMG_DATA_1219.png', 'KEMP_IMG_DATA_122.png', 'KEMP_IMG_DATA_1221.png', 'KEMP_IMG_DATA_1222.png', 'KEMP_IMG_DATA_1223.png', 'KEMP_IMG_DATA_1224.png', 'KEMP_IMG_DATA_1225.png', 'KEMP_IMG_DATA_1226.png', 'KEMP_IMG_DATA_1229.png', 'KEMP_IMG_DATA_123.png', 'KEMP_IMG_DATA_1230.png', 'KEMP_IMG_DATA_1231.png', 'KEMP_IMG_DATA_1232.png', 'KEMP_IMG_DATA_1234.png', 'KEMP_IMG_DATA_1233.png', 'KEMP_IMG_DATA_1235.png', 'KEMP_IMG_DATA_1237.png', 'KEMP_IMG_DATA_1236.png', 'KEMP_IMG_DATA_1238.png', 'KEMP_IMG_DATA_1240.png', 'KEMP_IMG_DATA_124.png', 'KEMP_IMG_DATA_1241.png', 'KEMP_IMG_DATA_1242.png', 'KEMP_IMG_DATA_1244.png', 'KEMP_IMG_DATA_1243.png', 'KEMP_IMG_DATA_1245.png', 'KEMP_IMG_DATA_1246.png', 'KEMP_IMG_DATA_1247.png', 'KEMP_IMG_DATA_1248.png', 'KEMP_IMG_DATA_125.png', 'KEMP_IMG_DATA_1249.png', 'KEMP_IMG_DATA_1251.png', 'KEMP_IMG_DATA_1252.png', 'KEMP_IMG_DATA_1253.png', 'KEMP_IMG_DATA_1254.png', 'KEMP_IMG_DATA_1256.png', 'KEMP_IMG_DATA_1255.png', 'KEMP_IMG_DATA_1257.png', 'KEMP_IMG_DATA_1258.png', 'KEMP_IMG_DATA_1259.png', 'KEMP_IMG_DATA_126.png', 'KEMP_IMG_DATA_1260.png', 'KEMP_IMG_DATA_1263.png', 'KEMP_IMG_DATA_1262.png', 'KEMP_IMG_DATA_1264.png', 'KEMP_IMG_DATA_1266.png', 'KEMP_IMG_DATA_1265.png', 'KEMP_IMG_DATA_1267.png', 'KEMP_IMG_DATA_1268.png', 'KEMP_IMG_DATA_1269.png', 'KEMP_IMG_DATA_127.png', 'KEMP_IMG_DATA_1274.png', 'KEMP_IMG_DATA_1275.png', 'KEMP_IMG_DATA_1276.png', 'KEMP_IMG_DATA_1278.png', 'KEMP_IMG_DATA_1281.png', 'KEMP_IMG_DATA_1279.png', 'KEMP_IMG_DATA_1282.png', 'KEMP_IMG_D ...
# ['Error_train_(107).png', 'Error_train_(101).png', 'Error_train_(111).png', 'Error_train_(119).png', 'Error_train_(112).png', 'Error_train_(113).png', 'Error_train_(118).png', 'Error_train_(106).png', 'Error_train_(114).png', 'Error_train_(102).png', 'Error_train_(103).png', 'Error_train_(105).png', 'Error_train_(108).png', 'Error_train_(116).png', 'Error_train_(121).png', 'Error_train_(120).png', 'Error_train_(109).png', 'Error_train_(110).png', 'Error_train_(115).png', 'Error_train_(104).png', 'Error_train_(117).png', 'Error_train_(100).png', 'Error_train_(130).png', 'Error_train_(132).png', 'Error_train_(124).png', 'Error_train_(141).png', 'Error_train_(136).png', 'Error_train_(134).png', 'Error_train_(137).png', 'Error_train_(138).png', 'Error_train_(127).png', 'Error_train_(139).png', 'Error_train_(125).png', 'Error_train_(135).png', 'Error_train_(133).png', 'Error_train_(123).png', 'Error_train_(143).png', 'Error_train_(128).png', 'Error_train_(122).png', 'Error_train_(140).png', 'Error_train_(126).png', 'Error_train_(142).png', 'Error_train_(131).png', 'Error_train_(129).png', 'Error_train_(146).png', 'Error_train_(144).png', 'Error_train_(153).png', 'Error_train_(154).png', 'Error_train_(149).png', 'Error_train_(147).png', 'Error_train_(152).png', 'Error_train_(145).png', 'Error_train_(151).png', 'Error_train_(148).png', 'Error_train_(150).png', 'Error_train_(164).png', 'Error_train_(161).png', 'Error_train_(159).png', 'Error_train_(155).png', 'Error_train_(163).png', 'Error_train_(165).png', 'Error_train_(157).png', 'Error_train_(162).png', 'Error_train_(158).png', 'Error_train_(160).png', 'Error_train_(156).png', 'Error_train_(183).png', 'Error_train_(175).png', 'Error_train_(178).png', 'Error_train_(187).png', 'Error_train_(186).png', 'Error_train_(185).png', 'Error_train_(171).png', 'Error_train_(184).png', 'Error_train_(166).png', 'Error_train_(168).png', 'Error_train_(181).png', 'Error_train_(180).png', 'Error_train_(167).png', 'Error_train_(182).png', 'Error_train_(179).png', 'Error_train_(169).png', 'Error_train_(176).png', 'Error_train_(173).png', 'Error_train_(170).png', 'Error_train_(177).png', 'Error_train_(172).png', 'Error_train_(174).png', 'Error_train_(195).png', 'Error_train_(198).png', 'Error_train_(202).png', 'Error_train_(197).png', 'Error_train_(204).png', 'Error_train_(207).png', 'Error_train_(203).png', 'Error_train_(200).png', 'Error_train_(194).png', 'Error_train_(201).png', 'Error_train_(206).png', 'Error_train_(199).png', 'Error_train_(209).png', 'Error_train_(193).png', 'Error_train_(192).png', 'Error_train_(205).png', 'Error_train_(189).png', 'Error_train_(188).png', 'Error_train_(190).png', 'Error_train_(196).png', 'Error_train_(208).png', 'Error_train_(191).png', 'Error_train_(13).png', 'Error_train_(16).png', 'Error_train_(18).png', 'Error_train_(17).png', 'Error_train_(15).png', 'Error_train_(12).png', 'Error_train_(14).png', 'Error_train_(19).png', 'Error_train_(21).png', 'Error_train_(22).png', 'Error_train_(20).png', 'Error_train_(316).png', 'Error_train_(318).png', 'Error_train_(315).png', 'Error_train_(309).png', 'Error_train_(314).png', 'Error_train_(313).png', 'Error_train_(310).png', 'Error_train_(317).png', 'Error_train_(311).png', 'Error_train_(312).png', 'Error_train_(319).png', 'Error_train_(343).png', 'Error_train_(347).png', 'Error_train_(351).png', 'Error_train_(333).png', 'Error_train_(338).png', 'Error_train_(342).png', 'Error_train_(346).png', 'Error_train_(341).png', 'Error_train_(350).png', 'Error_train_(336).png', 'Error_train_(326).png', 'Error_train_(331).png', 'Error_train_(325).png', 'Error_train_(328).png', 'Error_train_(344).png', 'Error_train_(330).png', 'Error_train_(321).png', 'Error_train_(322).png', 'Error_train_(327).png', 'Error_train_(345).png', 'Error_train_(352).png', 'Error_train_(332).png', 'Error_train_(349).png', 'Error_train_(340).png', 'Error_train_(324).png', 'Error_train_(339).png', 'Error_train_(323).png', 'Error_train_(335).png', 'Error_tra ...

# %%
# 각 디렉토리에 저장되어 있는 이미지 파일 수 확인

print('Total training G images :', len(os.listdir(train_G_dir)))
print('Total training B images :', len(os.listdir(train_B_dir)))

print('Total test G images :', len(os.listdir(test_G_dir)))
print('Total test B images :', len(os.listdir(test_B_dir)))
# Out:
# Total training G images : 1102
# Total training B images : 649
# Total test G images : 275
# Total test B images : 164

# %%
# 이미지 확인

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_G_pix = [os.path.join(train_G_dir, fname) for fname in train_G_fnames[pic_index-8:pic_index]]
next_B_pix = [os.path.join(train_B_dir, fname) for fname in train_B_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_G_pix+next_B_pix):
    sp = plt.subplot(nrows, ncols, i+1)
    sp.axis('OFF')
    
    img = mpimg.imread(img_path)
    plt.imshow(img)
    
plt.show()

# %% [markdown]
# ## 이미지 데이터 생성

# %%
# 이미지 정규화
train_datagen = ImageDataGenerator(rescale = 1./255) # 모든 이미지 원소값들을 255로 나누기

                                  
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만들기
# 변환된 이미지 데이터 생성
train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    batch_size=64, # 한번에 변환된 이미지 64개씩 만들어라 라는 것
                                                    color_mode='grayscale', # 흑백 이미지 처리
                                                    class_mode='binary', 
                                                    target_size=(256,256)) # target_size에 맞춰서 이미지의 크기가 조절된다

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  batch_size=32,
                                                  color_mode='grayscale',
                                                  class_mode='binary',
                                                  target_size=(256,256))
# 참고로, generator 생성시 batch_size x steps_per_epoch (model fit에서) <= 훈련 샘플 수 보다 작거나 같아야 한다.
# Out:
# Found 1751 images belonging to 2 classes.
# Found 439 images belonging to 2 classes.

# %%
# class 확인
train_generator.class_indices
# Out:
# {'Good': 0, 'bad': 1}

# %% [markdown]
# ## Augmentation 적용 확인

# %%
# 이미지 하나 불러오기
sample_img = mpimg.imread(next_G_pix[0])
plt.imshow(sample_img)
plt.show()

# %%
max_iter = 4
cnt = 1
sample_img2 = sample_img[np.newaxis, ...]
# 축을 하나 추가했는데, 하나의 이미지만 바꿔주는게 아니라 동시에 여러개의 이미지를 바꿔줄 수 있기에,
# 그림 개수/장수 까지 받아서 4차원으로 (개수/장수, h, w, channel) 이렇게 받는다
# 쉽게 말해, 받는 형식이 4차원이라서 4차원 형태로 만들어 준것

plt.figure(figsize=(10,10))
for img in train_datagen.flow(sample_img2):
    plt.subplot(1, max_iter, cnt)
    plt.imshow(image.array_to_img(img[0]))
    if cnt == max_iter:
        break
    cnt += 1

# %%
sample_img.shape
# Out:
# (720, 480, 4)

# %% [markdown]
# ## 모델링
#
# - 합성곱 신경망 모델 구성
# - 출력층의 활성화함수로 'sigmoid' 사용
#   - 0과 1 두 가지로 분류되는 'binary' 분류 문제에 적합하기 때문

# %%
# 합성곱 신경망 모델 구성하기
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 1)),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary() # 신경망의 구조 확인
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      160
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 28800)             0
#
#  dense_2 (Dense)             (None, 100)               2880100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 2,894,249
# Trainable params: 2,894,249
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델 학습
#
# - 손실 함수로 ‘binary_crossentropy’를 사용
# - 옵티마이저로는 RMSprop을 사용
#   - RMSprop(Root Mean Square Propagation) 알고리즘은 훈련 과정 중에 학습률을 적절하게 변화시켜 줌

# %%
# 모델 컴파일
# compile() 메서드를 이용해서 손실 함수 (loss function)와 옵티마이저 (optimizer)를 지정
model.compile(optimizer=RMSprop(learning_rate=0.001), # 옵티마이저로는 RMSprop 사용
              loss='binary_crossentropy', # 손실 함수로 ‘binary_crossentropy’ 사용
              metrics= ['accuracy'])

# %%
# 모델 훈련
history = model.fit_generator(train_generator, # train_generator안에 X값, y값 다 있으니 generator만 주면 된다
                              validation_data=test_generator, # validatino_generator안에도 검증용 X,y데이터들이 다 있으니 generator로 주면 됨
                              steps_per_epoch=16, # 한 번의 에포크(epoch)에서 훈련에 사용할 배치(batch)의 개수 지정; generator를 4번 부르겠다
                              epochs=30, # 데이터셋을 한 번 훈련하는 과정; epoch은 100 이상은 줘야한다
                              validation_steps=16, # 한 번의 에포크가 끝날 때, 검증에 사용되는 배치(batch)의 개수를 지정; validation_generator를 4번 불러서 나온 이미지들로 작업을 해라
                              verbose=2)
# 참고: validation_steps는 보통 내가 원하는 이미지 수에 flow할 때 지정한 batchsize로 나눈 값을 validation_steps로 지정
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/30
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 16 batches). You may need to use the repeat() function when building your dataset.
# 16/16 - 25s - loss: 0.8259 - accuracy: 0.6256 - val_loss: 0.3347 - val_accuracy: 0.9499 - 25s/epoch - 2s/step
# Epoch 2/30
# 16/16 - 15s - loss: 0.2638 - accuracy: 0.9084 - 15s/epoch - 912ms/step
# Epoch 3/30
# 16/16 - 15s - loss: 0.0521 - accuracy: 0.9858 - 15s/epoch - 922ms/step
# Epoch 4/30
# 16/16 - 15s - loss: 0.0875 - accuracy: 0.9583 - 15s/epoch - 918ms/step
# Epoch 5/30
# 16/16 - 15s - loss: 0.0231 - accuracy: 0.9922 - 15s/epoch - 957ms/step
# Epoch 6/30
# 16/16 - 15s - loss: 0.0032 - accuracy: 1.0000 - 15s/epoch - 953ms/step
# Epoch 7/30
# 16/16 - 15s - loss: 9.2679e-04 - accuracy: 1.0000 - 15s/epoch - 915ms/step
# Epoch 8/30
# 16/16 - 15s - loss: 3.4698e-04 - accuracy: 1.0000 - 15s/epoch - 920ms/step
# Epoch 9/30
# 16/16 - 15s - loss: 0.0500 - accuracy: 0.9847 - 15s/epoch - 915ms/step
# Epoch 10/30
# 16/16 - 15s - loss: 5.8238e-04 - accuracy: 1.0000 - 15s/epoch - 917ms/step
# Epoch 11/30
# 16/16 - 15s - loss: 1.5850e-04 - accuracy: 1.0000 - 15s/epoch - 915ms/step
# Epoch 12/30
# 16/16 - 15s - loss: 9.8296e-05 - accuracy: 1.0000 - 15s/epoch - 954ms/step
# Epoch 13/30
# 16/16 - 15s - loss: 4.8527e-05 - accuracy: 1.0000 - 15s/epoch - 953ms/step
# Epoch 14/30
# 16/16 - 15s - loss: 0.1548 - accuracy: 0.9573 - 15s/epoch - 915ms/step
# Epoch 15/30
# 16/16 - 15s - loss: 0.0024 - accuracy: 1.0000 - 15s/epoch - 957ms/step
# Epoch 16/30
# 16/16 - 15s - loss: 6.1117e-04 - accuracy: 1.0000 - 15s/epoch - 957ms/step
# Epoch 17/30
# 16/16 - 15s - loss: 1.2528e-04 - accuracy: 1.0000 - 15s/epoch - 920ms/step
# Epoch 18/30
# 16/16 - 15s - loss: 9.6214e-05 - accuracy: 1.0000 - 15s/epoch - 959ms/step
# Epoch 19/30
# 16/16 - 15s - loss: 0.0331 - accuracy: 0.9883 - 15s/epoch - 961ms/step
# Epoch 20/30
# 16/16 - 15s - loss: 0.0010 - accuracy: 1.0000 - 15s/epoch - 952ms/step
# Epoch 21/30
# 16/16 - 15s - loss: 3.3260e-04 - accuracy: 1.0000 - 15s/epoch - 954ms/step
# Epoch 22/30
# 16/16 - 15s - loss: 5.7435e-05 - accuracy: 1.0000 - 15s/epoch - 957ms/step
# Epoch 23/30
# 16/16 - 15s - loss: 3.8603e-05 - accuracy: 1.0000 - 15s/epoch - 915ms/step
# Epoch 24/30
# 16/16 - 15s - loss: 1.7671e-05 - accuracy: 1.0000 - 15s/epoch - 915ms/step
# Epoch 25/30
# 16/16 - 15s - loss: 5.3541e-06 - accuracy: 1.0000 - 15s/epoch - 921ms/step
# Epoch 26/30
# 16/16 - 15s - loss: 0.1456 - accuracy: 0.9664 - 15s/epoch - 915ms/step
# Epoch 27/30
# 16/16 - 15s - loss: 5.7102e-04 - accuracy: 1.0000 - 15s/epoch - 915ms/step
# Epoch 28/30
# 16/16 - 15s - loss: 1.2374e-04 - accuracy: 1.0000 - 15s/epoch - 955ms/step
# Epoch 29/30
# 16/16 - 15s - loss: 6.2348e-05 - accuracy: 1.0000 - 15s/epoch - 954ms/step
# Epoch 30/30
# 16/16 - 15s - loss: 2.4200e-05 - accuracy: 1.0000 - 15s/epoch - 917ms/step

# %%
history

# %% [markdown]
# ## 모델 평가

# %%
# 모델 성능 평가 (훈련 데이터)
model.evaluate(train_generator)
# Out:
# 28/28 [==============================] - 26s 928ms/step - loss: 3.2628e-06 - accuracy: 1.0000
# [3.26279428009002e-06, 1.0]

# %%
# 모델 성능 평가 (테스트 데이터)
model.evaluate(test_generator)
# Out:
# 14/14 [==============================] - 7s 467ms/step - loss: 1.1757e-11 - accuracy: 1.0000
# [1.1757299127335141e-11, 1.0]

# %%
# 정확도 및 손실 시각화
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c1909cea26e8> in <module>
#       8
#       9 plt.plot(epochs, acc, 'bo', label='Training accuracy')
# ---> 10 plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
#      11 plt.title('Training and validation accuracy')
#      12 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (30,) and (1,)

# %%
# 테스트 평가
from keras.preprocessing import image

# 테스트용 Good 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/only_test/'
test_G_dir = os.path.join(test_dir, 'Good/')
test_G_filenames = os.listdir(test_G_dir)
test_G_filenames

# 테스트용 Bad 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/only_test/'
test_B_dir = os.path.join(test_dir, 'bad/')
test_B_filenames = os.listdir(test_B_dir)
test_B_filenames

# Good,bad를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_GB_filenames = {}
dic_GB_filenames['Good'] = test_G_filenames
dic_GB_filenames['bad'] = test_B_filenames

# Good/Bad 분류 테스트
for GB, filenames in dic_GB_filenames.items():
    fig = plt.figure(figsize=(16,10))
    rows, cols = 2, 8
    for i, fn in enumerate(filenames):
        path = test_dir + GB + '/' + fn
        test_img = keras.utils.load_img(path, color_mode='grayscale', target_size=(256, 256), interpolation='bilinear')        
        x = keras.utils.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = model.predict(images, batch_size=16)
        
        fig.add_subplot(rows, cols, i+1)
        if classes[0]==0:
            # plt.title(fn + " is Good")
            plt.title(" is Good")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')

        else:
            plt.title(" is Bad")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
    plt.show();
# Out:
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/6dogma_sy/model/GB_class_cnn.h5')
print(type(loaded_model))
# Out:
# <class 'keras.engine.sequential.Sequential'>

# %%
# test 파일 그대로 넣은 경우

from keras.preprocessing import image

# 테스트용 Good 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized_aug/test/'
test_G_dir = os.path.join(test_dir, 'Good/')
test_G_filenames = os.listdir(test_G_dir)
test_G_filenames

# 테스트용 Bad 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized_aug/test/'
test_B_dir = os.path.join(test_dir, 'bad/')
test_B_filenames = os.listdir(test_B_dir)
test_B_filenames

# Good,bad를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_GB_filenames = {}
dic_GB_filenames['Good'] = test_G_filenames
dic_GB_filenames['bad'] = test_B_filenames


G_list = []
B_list = []
# Good/Bad 분류 테스트
for GB, filenames in dic_GB_filenames.items():
    fig = plt.figure(figsize=(16,10))
    rows, cols = 2, 276



    for i, fn in enumerate(filenames):
        path = test_dir + GB + '/' + fn
        test_img = keras.utils.load_img(path, color_mode='grayscale', target_size=(256, 256), interpolation='bilinear')        
        x = keras.utils.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = loaded_model.predict(images, batch_size=16)
        

        fig.add_subplot(rows, cols, i+1)
        if classes[0]==0:
            # plt.title(fn + " is Good")
            plt.title(" is Good")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()


        else:
            plt.title(" is Bad")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()
            
        
        if GB == 'Good':
          G_list.append(tmp[0][0])
        else:
          B_list.append(tmp[0][0])

    # plt.show()
    # print(G_list)
    # print(B_list)

# %%
print(f'양품 판별률 : {G_list.count(0)}/{len(G_list)} = {(G_list.count(0)/len(G_list))*100:.2f}%')
print(f'불량 판별률 : {B_list.count(1)}/{len(B_list)} = {(B_list.count(1)/len(B_list))*100:.2f}%')
print(f'전체 정확도 : {G_list.count(0)+B_list.count(1)}/{len(G_list)+len(B_list)} = {(G_list.count(0)+B_list.count(1))/(len(G_list)+len(B_list))*100:.2f}%')
print(f'전체 오차율 : {G_list.count(1)+B_list.count(0)}/{len(G_list)+len(B_list)} = {(G_list.count(1)+B_list.count(0))/(len(G_list)+len(B_list))*100:.2f}%')
# Out:
# 양품 판별률 : 275/275 = 100.00%
# 불량 판별률 : 164/164 = 100.00%
# 전체 정확도 : 439/439 = 100.00%
# 전체 오차율 : 0/439 = 0.00%

# %%
# 파일 압축 풀기
# %cd 압축을 풀 경로
# !unzip -qq "압축파일 Path"

# %cd /content/drive/MyDrive/6dogma_sy/res
# !unzip -qq "/content/drive/MyDrive/6dogma_sy/res/resized.zip"
# Out:
# /content/drive/MyDrive/6dogma_sy/res

# %%
# 증강 안 한 원본 test 데이터

from keras.preprocessing import image

# 테스트용 Good 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized/test/'
test_G_dir = os.path.join(test_dir, 'Good/')
test_G_filenames = os.listdir(test_G_dir)
test_G_filenames

# 테스트용 Bad 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized/test/'
test_B_dir = os.path.join(test_dir, 'bad/')
test_B_filenames = os.listdir(test_B_dir)
test_B_filenames

# Good,bad를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_GB_filenames = {}
dic_GB_filenames['Good'] = test_G_filenames
dic_GB_filenames['bad'] = test_B_filenames


G_list = []
B_list = []
# Good/Bad 분류 테스트
for GB, filenames in dic_GB_filenames.items():
    fig = plt.figure(figsize=(16,10))
    rows, cols = 2, 276



    for i, fn in enumerate(filenames):
        path = test_dir + GB + '/' + fn
        test_img = keras.utils.load_img(path, color_mode='grayscale', target_size=(256, 256), interpolation='bilinear')        
        x = keras.utils.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = loaded_model.predict(images, batch_size=16)
        

        fig.add_subplot(rows, cols, i+1)
        if classes[0]==0:
            # plt.title(fn + " is Good")
            plt.title(" is Good")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()


        else:
            plt.title(" is Bad")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()
            
        
        if GB == 'Good':
          G_list.append(tmp[0][0])
        else:
          B_list.append(tmp[0][0])

    # plt.show()
    # print(G_list)
    # print(B_list)

# %%
print(f'양품 판별률 : {G_list.count(0)}/{len(G_list)} = {(G_list.count(0)/len(G_list))*100:.2f}%')
print(f'불량 판별률 : {B_list.count(1)}/{len(B_list)} = {(B_list.count(1)/len(B_list))*100:.2f}%')
print(f'전체 정확도 : {G_list.count(0)+B_list.count(1)}/{len(G_list)+len(B_list)} = {(G_list.count(0)+B_list.count(1))/(len(G_list)+len(B_list))*100:.2f}%')
print(f'전체 오차율 : {G_list.count(1)+B_list.count(0)}/{len(G_list)+len(B_list)} = {(G_list.count(1)+B_list.count(0))/(len(G_list)+len(B_list))*100:.2f}%')
# Out:
# 양품 판별률 : 276/276 = 100.00%
# 불량 판별률 : 14/15 = 93.33%
# 전체 정확도 : 290/291 = 99.66%
# 전체 오차율 : 1/291 = 0.34%

# %%
# 원본 test 데이터 2배 증강 -> 총 30개
from keras.preprocessing import image

# 테스트용 Good 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized/test/'
test_G_dir = os.path.join(test_dir, 'Good/')
test_G_filenames = os.listdir(test_G_dir)
test_G_filenames

# 테스트용 Bad 이미지 경로 설정
test_dir = '/content/drive/MyDrive/6dogma_sy/res/resized/test/'
test_B_dir = os.path.join(test_dir, 'bad/')
test_B_filenames = os.listdir(test_B_dir)
test_B_filenames

# Good,bad를 key로, 이미지 파일 이름들을 value로 dictionary 생성
dic_GB_filenames = {}
dic_GB_filenames['Good'] = test_G_filenames
dic_GB_filenames['bad'] = test_B_filenames


G_list = []
B_list = []
# Good/Bad 분류 테스트
for GB, filenames in dic_GB_filenames.items():
    fig = plt.figure(figsize=(16,10))
    rows, cols = 2, 276



    for i, fn in enumerate(filenames):
        path = test_dir + GB + '/' + fn
        test_img = keras.utils.load_img(path, color_mode='grayscale', target_size=(256, 256), interpolation='bilinear')        
        x = keras.utils.img_to_array(test_img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        classes = loaded_model.predict(images, batch_size=16)
        

        fig.add_subplot(rows, cols, i+1)
        if classes[0]==0:
            # plt.title(fn + " is Good")
            plt.title(" is Good")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()


        else:
            plt.title(" is Bad")
            plt.axis('off')
            plt.imshow(test_img, cmap='gray')
            tmp = classes.tolist()
            
        
        if GB == 'Good':
          G_list.append(tmp[0][0])
        else:
          B_list.append(tmp[0][0])

    # plt.show()
    # print(G_list)
    # print(B_list)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
print(f'양품 판별률 : {G_list.count(0)}/{len(G_list)} = {(G_list.count(0)/len(G_list))*100:.2f}%')
print(f'불량 판별률 : {B_list.count(1)}/{len(B_list)} = {(B_list.count(1)/len(B_list))*100:.2f}%')
print(f'전체 정확도 : {G_list.count(0)+B_list.count(1)}/{len(G_list)+len(B_list)} = {(G_list.count(0)+B_list.count(1))/(len(G_list)+len(B_list))*100:.2f}%')
print(f'전체 오차율 : {G_list.count(1)+B_list.count(0)}/{len(G_list)+len(B_list)} = {(G_list.count(1)+B_list.count(0))/(len(G_list)+len(B_list))*100:.2f}%')
# Out:
# 양품 판별률 : 276/276 = 100.00%
# 불량 판별률 : 28/30 = 93.33%
# 전체 정확도 : 304/306 = 99.35%
# 전체 오차율 : 2/306 = 0.65%
